# %% [markdown]
# <a href="https://colab.research.google.com/github/Orshikhbayar/ml/blob/main/Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import csv
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer
from datetime import datetime, timedelta, timezone
import numpy as np
import pandas as pd
from keras.models import Sequential
from keras.layers import LSTM, Dense
from sklearn.preprocessing import MinMaxScaler
import ipywidgets as widgets
from IPython.display import display
import yfinance as yf

# Download the required resource for sentiment analysis
nltk.download('vader_lexicon')

# Load the NLTK sentiment intensity analyzer
sia = SentimentIntensityAnalyzer()

# Fetch available tickers from Yahoo Finance
tickers = ['BTC-USD', 'PXP-USD', 'XRP-USD', 'ETH-USD', 'XDC-USD', 'MCH-USD', 'XLM-USD', 'ETC-USD', 'REV-USD', 'DOGE-USD', '1INCH-USD', 'ADA-USD', 'VET-USD', 'VAL-USD', 'HBAR-USD', 'RSR-USD', 'DFI-USD', 'LTC-USD', 'TRX-USD', 'NEO-USD', 'DGB-USD', 'BCH-USD', 'ZRX-USD', 'DOT-USD','PEPE-USD', 'DAI-USD', 'SOL-USD', 'VRA-USD', 'ENJ-USD', 'AVAX-USD', 'GALA-USD', 'ALGO-USD',
           'USDC-USD', 'OMG-USD', 'GRT-USD', 'BAT-USD', 'LINK-USD', 'SC-USD', 'COVN-USD', 'FTM-USD',
           'ZEC-USD', 'DASH-USD', 'WAVES-USD', 'UNI-USD', 'XTZ-USD', 'CRO-USD', 'ATOM-USD', 'CRV-USD',
           'QTUM-USD', 'CELO-USD', 'COMP-USD', 'ETHW-USD', 'AAVE-USD', 'MATIC-USD', 'SNX-USD', 'OCEAN-USD', 'SG-USD', '1ECO-USD', 'JASMY-USD', 'RVN-USD', 'DCR-USD',
           'FIL-USD', 'EOS-USD', 'APE-USD', 'XEM-USD', 'R1-USD', 'ARDX-USD', 'XCN-USD', 'SAND-USD ', 'GXE-USD', 'AKT-USD', 'AXS-USD', 'B2M-USD', 'BAND-USD', 'CEL-USD',
           'DAF-USD', 'GMT-USD', 'HNS-USD', 'IOTX-USD', 'KLAY-USD', 'KOK-USD', 'KSM-USD',
           'MKR-USD', 'MNW-USD', 'MYCE-USD', 'ONT-USD', 'PROS-USD', 'RSV-USD', 'SOLVE-USD', 'TRAC-USD', 'TUSD-USD', 'UMA-USD', 'WBTC-USD' ]

# Create dropdown menu widget for cryptocurrency selection
cryptocurrency_dropdown = widgets.Dropdown(options=tickers, description='Cryptocurrency:')

# Load the data from Yahoo Finance
def load_data(cryptocurrency):
    try:
        data = yf.download(cryptocurrency, period="max")
        data.reset_index(inplace=True)
        data.drop_duplicates(subset='Date', inplace=True)
        data.fillna(0, inplace=True)
        data['date'] = pd.to_datetime(data['Date'])
        return data
    except KeyError:
        print(f"Error: No data available for {cryptocurrency}.")
        return pd.DataFrame()

# Create widgets for user input
investment_amount_widget = widgets.IntSlider(value=1000, min=100, max=10000, step=100, description='Investment Amount ($)')
target_date_widget = widgets.DatePicker(description='Target Date')
predict_button = widgets.Button(description='Predict')

def predict_button_clicked(b):
    # Retrieve user input values
    investment_amount = investment_amount_widget.value
    target_date = target_date_widget.value
    cryptocurrency = cryptocurrency_dropdown.value

    # Load the data for the selected cryptocurrency
    data = load_data(cryptocurrency)

    if data.empty:
        return

    # Prepare the data for prediction
    target_column = 'Close'
    feature_columns = ['Open', 'High', 'Low', 'Volume']

    target = data[target_column].values
    features = data[feature_columns].values

    target_scaler = MinMaxScaler(feature_range=(0, 1))
    feature_scaler = MinMaxScaler(feature_range=(0, 1))

    scaled_target = target_scaler.fit_transform(target.reshape(-1, 1))
    scaled_features = feature_scaler.fit_transform(features)

    train_size = int(len(data) * 0.8)
    train_target = scaled_target[:train_size]
    train_features = scaled_features[:train_size]
    test_target = scaled_target[train_size:]
    test_features = scaled_features[train_size:]

    train_features = np.reshape(train_features, (train_features.shape[0], 1, train_features.shape[1]))
    test_features = np.reshape(test_features, (test_features.shape[0], 1, test_features.shape[1]))

    model = Sequential()
    model.add(LSTM(100, input_shape=(1, len(feature_columns))))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer='adam')

    model.fit(train_features, train_target, epochs=50, batch_size=64, verbose=2)

    current_date = datetime.now().date()  # Convert to datetime.date
    last_known_date = data['date'].max().date()  # Convert to datetime.date
    days_to_predict = (target_date - last_known_date).days

    prediction_dates = [target_date]

    predictions = []

    for prediction_date in prediction_dates:
        days_to_predict = (prediction_date - current_date).days
        last_features = test_features[-1:]  # Use the last available features for prediction

        for _ in range(days_to_predict):
            prediction = model.predict(last_features)
            predictions.append(prediction[0][0])

            # Update the features for the next prediction
            last_features[0][0][0] = prediction[0][0]
            last_features = np.array(last_features)

    predicted_prices = target_scaler.inverse_transform(np.array(predictions).reshape(-1, 1))

    print("Predicted Prices:")
    for i, prediction_date in enumerate(prediction_dates):
        print(f"{prediction_date.strftime('%Y-%m-%d')}: {predicted_prices[i][0]:.4f}")

    # Calculate investment value and profit/loss at each time range
    investment_values = []
    profits_losses = []
    investment_date = current_date  # Date of investment

    for i, prediction_date in enumerate(prediction_dates):
        investment_price = target_scaler.inverse_transform(test_target[-1:])[0][0]
        current_price = predicted_prices[i][0]
        investment_value = investment_amount / investment_price * current_price
        investment_values.append(investment_value)

        # Calculate profit/loss
        profit_loss = investment_value - investment_amount
        profits_losses.append(profit_loss)

    print(f"\nInvestment Details (Amount: {investment_amount} USD):")
    for i, prediction_date in enumerate(prediction_dates):
        print(f"{prediction_date.strftime('%Y-%m-%d')}: "
              f"Investment Value: {investment_values[i]:.2f} USD, "
              f"Profit/Loss: {profits_losses[i]:.2f} USD")

    # Perform Sentiment Analysis
    # Calculate the date range
    today = datetime.now().date()
    from_date = (today - timedelta(days=7)).isoformat()
    to_date = today.isoformat()

    # Set your API key and search parameters
    api_key = "ce600ab964514d429fb25b58a005dde6"
    search_query = cryptocurrency
    language = "en"

    # Define the API endpoint URL
    url = f"https://newsapi.org/v2/everything?q={search_query}&from={from_date}&to={to_date}&language={language}&apiKey={api_key}"

    # Send the HTTP request to the API for News data
    response = requests.get(url)

    # Check if the request was successful
    if response.status_code == 200:
        # Parse the JSON response
        data = response.json()

        # Extract the articles from the response
        articles = data["articles"]

        # Define the CSV filename for News data
        filename = "articles.csv"

        # Open the CSV file in write mode and download the articles
        with open(filename, "w", newline="", encoding="utf-8") as file:
            # Create a CSV writer object
            writer = csv.writer(file)

            # Write the header row
            writer.writerow(["Title", "Description", "Source", "URL", "Published At"])

            # Write each article to a row in the CSV file
            for article in articles:
                title = article["title"]
                description = article["description"]
                source = article["source"]["name"]
                url = article["url"]
                published_at = article["publishedAt"]

                # Write the article data to the CSV file
                writer.writerow([title, description, source, url, published_at])

        print(f"\nArticles have been downloaded and saved to {filename}")

        # Read the articles from the CSV file
        articles = []
        dates = []
        with open(filename, "r", encoding="utf-8") as file:
            reader = csv.reader(file)
            next(reader)  # Skip the header row
            for row in reader:
                title = row[0]
                description = row[1]
                published_at = row[4]
                articles.append(description)
                dates.append(datetime.strptime(published_at, "%Y-%m-%dT%H:%M:%SZ").date())

        # Sort the articles and dates in chronological order
        articles = [a for _, a in sorted(zip(dates, articles))]
        dates.sort()

        # Analyze the sentiment of each article
        sentiments = []
        for article in articles:
            sentiment = sia.polarity_scores(article)
            sentiments.append(sentiment)

        # Merge sentiment scores for each day
        daily_sentiments = {}
        for i, sentiment in enumerate(sentiments):
            date = dates[i]
            if date not in daily_sentiments:
                daily_sentiments[date] = {
                    "compound": [],
                    "positive": [],
                    "negative": [],
                    "neutral": []
                }
            daily_sentiments[date]["compound"].append(sentiment["compound"])
            daily_sentiments[date]["positive"].append(sentiment["pos"])
            daily_sentiments[date]["negative"].append(sentiment["neg"])
            daily_sentiments[date]["neutral"].append(sentiment["neu"])

        # Calculate average sentiment scores for each day
        average_sentiments = {
            "dates": [],
            "compound": [],
            "positive": [],
            "negative": [],
            "neutral": []
        }
        for date, scores in daily_sentiments.items():
            average_compound = sum(scores["compound"]) / len(scores["compound"])
            average_positive = sum(scores["positive"]) / len(scores["positive"])
            average_negative = sum(scores["negative"]) / len(scores["negative"])
            average_neutral = sum(scores["neutral"]) / len(scores["neutral"])
            average_sentiments["dates"].append(date)
            average_sentiments["compound"].append(average_compound)
            average_sentiments["positive"].append(average_positive)
            average_sentiments["negative"].append(average_negative)
            average_sentiments["neutral"].append(average_neutral)

        # Convert average sentiment data to DataFrame
        sentiment_df = pd.DataFrame(average_sentiments)

        # Display sentiment DataFrame
        print("\nSentiment Analysis:")
        print(sentiment_df)

    else:
        print(f"Error: Failed to fetch news data for {cryptocurrency}.")

# Register button click event handler
predict_button.on_click(predict_button_clicked)

# Display the widgets and button
display(cryptocurrency_dropdown, investment_amount_widget, target_date_widget, predict_button)
# Out:
# Dropdown(description='Prediction Mode:', options=('Single Crypto Prediction', 'Multi Crypto Prediction'), valu…
# Button(description='Select', style=ButtonStyle())
# Dropdown(description='Cryptocurrency:', options=('BTC-USD', 'PXP-USD', 'XRP-USD', 'ETH-USD', 'XDC-USD', 'MCH-U…
# IntSlider(value=1000, description='Investment Amount ($)', max=10000, min=100, step=100)
# DatePicker(value=None, description='Target Date')
# Button(description='Predict', style=ButtonStyle())
# IntSlider(value=1000, description='Investment Amount ($)', max=10000, min=100, step=100)
# DatePicker(value=None, description='Target Date')
# [*********************100%***********************]  1 of 1 completed
# Epoch 1/50
# 21/21 - 7s - loss: 0.0365 - 7s/epoch - 350ms/step
# Epoch 2/50
# 21/21 - 0s - loss: 0.0139 - 78ms/epoch - 4ms/step
# Epoch 3/50
# 21/21 - 0s - loss: 0.0055 - 71ms/epoch - 3ms/step
# Epoch 4/50
# 21/21 - 0s - loss: 0.0010 - 70ms/epoch - 3ms/step
# Epoch 5/50
# 21/21 - 0s - loss: 1.5236e-04 - 71ms/epoch - 3ms/step
# Epoch 6/50
# 21/21 - 0s - loss: 1.4112e-04 - 79ms/epoch - 4ms/step
# Epoch 7/50
# 21/21 - 0s - loss: 1.3074e-04 - 100ms/epoch - 5ms/step
# Epoch 8/50
# 21/21 - 0s - loss: 1.2461e-04 - 100ms/epoch - 5ms/step
# Epoch 9/50
# 21/21 - 0s - loss: 1.2059e-04 - 98ms/epoch - 5ms/step
# Epoch 10/50
# 21/21 - 0s - loss: 1.1606e-04 - 96ms/epoch - 5ms/step
# Epoch 11/50
# 21/21 - 0s - loss: 1.1143e-04 - 92ms/epoch - 4ms/step
# Epoch 12/50
# 21/21 - 0s - loss: 1.0787e-04 - 91ms/epoch - 4ms/step
# Epoch 13/50
# 21/21 - 0s - loss: 1.0359e-04 - 109ms/epoch - 5ms/step
# Epoch 14/50
# 21/21 - 0s - loss: 9.9474e-05 - 97ms/epoch - 5ms/step
# Epoch 15/50
# 21/21 - 0s - loss: 9.6452e-05 - 100ms/epoch - 5ms/step
# Epoch 16/50
# 21/21 - 0s - loss: 9.3255e-05 - 100ms/epoch - 5ms/step
# Epoch 17/50
# 21/21 - 0s - loss: 9.0091e-05 - 98ms/epoch - 5ms/step
# Epoch 18/50
# 21/21 - 0s - loss: 8.6257e-05 - 101ms/epoch - 5ms/step
# Epoch 19/50
# 21/21 - 0s - loss: 8.3209e-05 - 102ms/epoch - 5ms/step
# Epoch 20/50
# 21/21 - 0s - loss: 8.0309e-05 - 105ms/epoch - 5ms/step
# Epoch 21/50
# 21/21 - 0s - loss: 7.7704e-05 - 99ms/epoch - 5ms/step
# Epoch 22/50
# 21/21 - 0s - loss: 7.5762e-05 - 97ms/epoch - 5ms/step
# Epoch 23/50
# 21/21 - 0s - loss: 7.2686e-05 - 103ms/epoch - 5ms/step
# Epoch 24/50
# 21/21 - 0s - loss: 7.1318e-05 - 100ms/epoch - 5ms/step
# Epoch 25/50
# 21/21 - 0s - loss: 6.9328e-05 - 100ms/epoch - 5ms/step
# Epoch 26/50
# 21/21 - 0s - loss: 6.6523e-05 - 100ms/epoch - 5ms/step
# Epoch 27/50
# 21/21 - 0s - loss: 6.4663e-05 - 82ms/epoch - 4ms/step
# Epoch 28/50
# 21/21 - 0s - loss: 6.2986e-05 - 68ms/epoch - 3ms/step
# Epoch 29/50
# 21/21 - 0s - loss: 6.1333e-05 - 75ms/epoch - 4ms/step
# Epoch 30/50
# 21/21 - 0s - loss: 6.0112e-05 - 66ms/epoch - 3ms/step
# Epoch 31/50
# 21/21 - 0s - loss: 5.8125e-05 - 67ms/epoch - 3ms/step
# Epoch 32/50
# 21/21 - 0s - loss: 5.6664e-05 - 68ms/epoch - 3ms/step
# Epoch 33/50
# 21/21 - 0s - loss: 5.5271e-05 - 66ms/epoch - 3ms/step
# Epoch 34/50
# 21/21 - 0s - loss: 5.5011e-05 - 69ms/epoch - 3ms/step
# Epoch 35/50
# 21/21 - 0s - loss: 5.3198e-05 - 79ms/epoch - 4ms/step
# Epoch 36/50
# 21/21 - 0s - loss: 5.1983e-05 - 74ms/epoch - 4ms/step
# Epoch 37/50
# 21/21 - 0s - loss: 5.1106e-05 - 67ms/epoch - 3ms/step
# Epoch 38/50
# 21/21 - 0s - loss: 5.0500e-05 - 66ms/epoch - 3ms/step
# Epoch 39/50
# 21/21 - 0s - loss: 4.9413e-05 - 68ms/epoch - 3ms/step
# Epoch 40/50
# 21/21 - 0s - loss: 4.8337e-05 - 68ms/epoch - 3ms/step
# Epoch 41/50
# 21/21 - 0s - loss: 4.8005e-05 - 67ms/epoch - 3ms/step
# Epoch 42/50
# 21/21 - 0s - loss: 4.6839e-05 - 68ms/epoch - 3ms/step
# Epoch 43/50
# 21/21 - 0s - loss: 4.6367e-05 - 68ms/epoch - 3ms/step
# Epoch 44/50
# 21/21 - 0s - loss: 4.6527e-05 - 69ms/epoch - 3ms/step
# Epoch 45/50
# 21/21 - 0s - loss: 4.6066e-05 - 74ms/epoch - 4ms/step
# Epoch 46/50
# 21/21 - 0s - loss: 4.5761e-05 - 69ms/epoch - 3ms/step
# Epoch 47/50
# 21/21 - 0s - loss: 4.4385e-05 - 68ms/epoch - 3ms/step
# Epoch 48/50
# 21/21 - 0s - loss: 4.3714e-05 - 69ms/epoch - 3ms/step
# Epoch 49/50
# 21/21 - 0s - loss: 4.3888e-05 - 79ms/epoch - 4ms/step
# Epoch 50/50
# 21/21 - 0s - loss: 4.3597e-05 - 67ms/epoch - 3ms/step
# 1/1 [==============================] - 0s 341ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# BTC-USD prediction completed.
# BTC-USD: Predicted Price: 29111.2266, Risk Score: 0.00%
# [*********************100%***********************]  1 of 1 completed
# Epoch 1/50
# 6/6 - 2s - loss: 0.0834 - 2s/epoch - 319ms/step
# Epoch 2/50
# 6/6 - 0s - loss: 0.0627 - 22ms/epoch - 4ms/step
# Epoch 3/50
# 6/6 - 0s - loss: 0.0459 - 23ms/epoch - 4ms/step
# Epoch 4/50
# 6/6 - 0s - loss: 0.0333 - 22ms/epoch - 4ms/step
# Epoch 5/50
# 6/6 - 0s - loss: 0.0244 - 22ms/epoch - 4ms/step
# Epoch 6/50
# 6/6 - 0s - loss: 0.0199 - 24ms/epoch - 4ms/step
# Epoch 7/50
# 6/6 - 0s - loss: 0.0163 - 24ms/epoch - 4ms/step
# Epoch 8/50
# 6/6 - 0s - loss: 0.0143 - 23ms/epoch - 4ms/step
# Epoch 9/50
# 6/6 - 0s - loss: 0.0118 - 22ms/epoch - 4ms/step
# Epoch 10/50
# 6/6 - 0s - loss: 0.0096 - 22ms/epoch - 4ms/step
# Epoch 11/50
# 6/6 - 0s - loss: 0.0075 - 22ms/epoch - 4ms/step
# Epoch 12/50
# 6/6 - 0s - loss: 0.0058 - 22ms/epoch - 4ms/step
# Epoch 13/50
# 6/6 - 0s - loss: 0.0044 - 23ms/epoch - 4ms/step
# Epoch 14/50
# 6/6 - 0s - loss: 0.0033 - 23ms/epoch - 4ms/step
# Epoch 15/50
# 6/6 - 0s - loss: 0.0025 - 22ms/epoch - 4ms/step
# Epoch 16/50
# 6/6 - 0s - loss: 0.0019 - 21ms/epoch - 4ms/step
# Epoch 17/50
# 6/6 - 0s - loss: 0.0015 - 22ms/epoch - 4ms/step
# Epoch 18/50
# 6/6 - 0s - loss: 0.0013 - 22ms/epoch - 4ms/step
# Epoch 19/50
# 6/6 - 0s - loss: 0.0011 - 24ms/epoch - 4ms/step
# Epoch 20/50
# 6/6 - 0s - loss: 0.0010 - 22ms/epoch - 4ms/step
# Epoch 21/50
# 6/6 - 0s - loss: 9.5833e-04 - 24ms/epoch - 4ms/step
# Epoch 22/50
# 6/6 - 0s - loss: 9.0821e-04 - 23ms/epoch - 4ms/step
# Epoch 23/50
# 6/6 - 0s - loss: 8.7266e-04 - 23ms/epoch - 4ms/step
# Epoch 24/50
# 6/6 - 0s - loss: 8.4030e-04 - 22ms/epoch - 4ms/step
# Epoch 25/50
# 6/6 - 0s - loss: 8.1607e-04 - 22ms/epoch - 4ms/step
# Epoch 26/50
# 6/6 - 0s - loss: 7.9189e-04 - 22ms/epoch - 4ms/step
# Epoch 27/50
# 6/6 - 0s - loss: 7.7655e-04 - 22ms/epoch - 4ms/step
# Epoch 28/50
# 6/6 - 0s - loss: 7.6198e-04 - 23ms/epoch - 4ms/step
# Epoch 29/50
# 6/6 - 0s - loss: 7.5126e-04 - 24ms/epoch - 4ms/step
# Epoch 30/50
# 6/6 - 0s - loss: 7.4408e-04 - 23ms/epoch - 4ms/step
# Epoch 31/50
# 6/6 - 0s - loss: 7.3793e-04 - 22ms/epoch - 4ms/step
# Epoch 32/50
# 6/6 - 0s - loss: 7.3368e-04 - 22ms/epoch - 4ms/step
# Epoch 33/50
# 6/6 - 0s - loss: 7.2990e-04 - 21ms/epoch - 4ms/step
# Epoch 34/50
# 6/6 - 0s - loss: 7.2741e-04 - 25ms/epoch - 4ms/step
# Epoch 35/50
# 6/6 - 0s - loss: 7.2621e-04 - 27ms/epoch - 4ms/step
# Epoch 36/50
# 6/6 - 0s - loss: 7.2310e-04 - 28ms/epoch - 5ms/step
# Epoch 37/50
# 6/6 - 0s - loss: 7.2174e-04 - 22ms/epoch - 4ms/step
# Epoch 38/50
# 6/6 - 0s - loss: 7.2046e-04 - 23ms/epoch - 4ms/step
# Epoch 39/50
# 6/6 - 0s - loss: 7.1923e-04 - 23ms/epoch - 4ms/step
# Epoch 40/50
# 6/6 - 0s - loss: 7.1923e-04 - 22ms/epoch - 4ms/step
# Epoch 41/50
# 6/6 - 0s - loss: 7.1841e-04 - 22ms/epoch - 4ms/step
# Epoch 42/50
# 6/6 - 0s - loss: 7.1661e-04 - 22ms/epoch - 4ms/step
# Epoch 43/50
# 6/6 - 0s - loss: 7.1554e-04 - 26ms/epoch - 4ms/step
# Epoch 44/50
# 6/6 - 0s - loss: 7.1479e-04 - 23ms/epoch - 4ms/step
# Epoch 45/50
# 6/6 - 0s - loss: 7.1696e-04 - 23ms/epoch - 4ms/step
# Epoch 46/50
# 6/6 - 0s - loss: 7.1313e-04 - 23ms/epoch - 4ms/step
# Epoch 47/50
# 6/6 - 0s - loss: 7.1204e-04 - 28ms/epoch - 5ms/step
# Epoch 48/50
# 6/6 - 0s - loss: 7.1263e-04 - 22ms/epoch - 4ms/step
# Epoch 49/50
# 6/6 - 0s - loss: 7.1196e-04 - 22ms/epoch - 4ms/step
# Epoch 50/50
# 6/6 - 0s - loss: 7.1205e-04 - 21ms/epoch - 4ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 17ms/step
# PXP-USD prediction completed.
# PXP-USD: Predicted Price: 0.0141, Risk Score: 4.58%
# [*********************100%***********************]  1 of 1 completed
# Epoch 1/50
# 14/14 - 2s - loss: 0.0198 - 2s/epoch - 139ms/step
# Epoch 2/50
# 14/14 - 0s - loss: 0.0083 - 52ms/epoch - 4ms/step
# Epoch 3/50
# 14/14 - 0s - loss: 0.0059 - 65ms/epoch - 5ms/step
# Epoch 4/50
# 14/14 - 0s - loss: 0.0042 - 47ms/epoch - 3ms/step
# Epoch 5/50
# 14/14 - 0s - loss: 0.0029 - 47ms/epoch - 3ms/step
# Epoch 6/50
# 14/14 - 0s - loss: 0.0018 - 46ms/epoch - 3ms/step
# Epoch 7/50
# 14/14 - 0s - loss: 0.0011 - 46ms/epoch - 3ms/step
# Epoch 8/50
# 14/14 - 0s - loss: 5.9945e-04 - 54ms/epoch - 4ms/step
# Epoch 9/50
# 14/14 - 0s - loss: 3.9610e-04 - 47ms/epoch - 3ms/step
# Epoch 10/50
# 14/14 - 0s - loss: 3.0107e-04 - 51ms/epoch - 4ms/step
# Epoch 11/50
# 14/14 - 0s - loss: 2.5325e-04 - 47ms/epoch - 3ms/step
# Epoch 12/50
# 14/14 - 0s - loss: 2.2564e-04 - 47ms/epoch - 3ms/step
# Epoch 13/50
# 14/14 - 0s - loss: 2.0580e-04 - 52ms/epoch - 4ms/step
# Epoch 14/50
# 14/14 - 0s - loss: 1.9374e-04 - 47ms/epoch - 3ms/step
# Epoch 15/50
# 14/14 - 0s - loss: 1.8724e-04 - 47ms/epoch - 3ms/step
# Epoch 16/50
# 14/14 - 0s - loss: 1.8071e-04 - 52ms/epoch - 4ms/step
# Epoch 17/50
# 14/14 - 0s - loss: 1.7710e-04 - 77ms/epoch - 5ms/step
# Epoch 18/50
# 14/14 - 0s - loss: 1.7281e-04 - 66ms/epoch - 5ms/step
# Epoch 19/50
# 14/14 - 0s - loss: 1.7889e-04 - 69ms/epoch - 5ms/step
# Epoch 20/50
# 14/14 - 0s - loss: 1.7071e-04 - 74ms/epoch - 5ms/step
# Epoch 21/50
# 14/14 - 0s - loss: 1.6651e-04 - 69ms/epoch - 5ms/step
# Epoch 22/50
# 14/14 - 0s - loss: 1.6354e-04 - 73ms/epoch - 5ms/step
# Epoch 23/50
# 14/14 - 0s - loss: 1.6241e-04 - 76ms/epoch - 5ms/step
# Epoch 24/50
# 14/14 - 0s - loss: 1.5975e-04 - 66ms/epoch - 5ms/step
# Epoch 25/50
# 14/14 - 0s - loss: 1.5938e-04 - 64ms/epoch - 5ms/step
# Epoch 26/50
# 14/14 - 0s - loss: 1.5708e-04 - 67ms/epoch - 5ms/step
# Epoch 27/50
# 14/14 - 0s - loss: 1.5467e-04 - 65ms/epoch - 5ms/step
# Epoch 28/50
# 14/14 - 0s - loss: 1.5293e-04 - 67ms/epoch - 5ms/step
# Epoch 29/50
# 14/14 - 0s - loss: 1.5166e-04 - 69ms/epoch - 5ms/step
# Epoch 30/50
# 14/14 - 0s - loss: 1.4945e-04 - 68ms/epoch - 5ms/step
# Epoch 31/50
# 14/14 - 0s - loss: 1.4859e-04 - 66ms/epoch - 5ms/step
# Epoch 32/50
# 14/14 - 0s - loss: 1.4896e-04 - 66ms/epoch - 5ms/step
# Epoch 33/50
# 14/14 - 0s - loss: 1.4843e-04 - 64ms/epoch - 5ms/step
# Epoch 34/50
# 14/14 - 0s - loss: 1.4579e-04 - 65ms/epoch - 5ms/step
# Epoch 35/50
# 14/14 - 0s - loss: 1.4352e-04 - 66ms/epoch - 5ms/step
# Epoch 36/50
# 14/14 - 0s - loss: 1.4160e-04 - 66ms/epoch - 5ms/step
# Epoch 37/50
# 14/14 - 0s - loss: 1.4023e-04 - 64ms/epoch - 5ms/step
# Epoch 38/50
# 14/14 - 0s - loss: 1.4245e-04 - 64ms/epoch - 5ms/step
# Epoch 39/50
# 14/14 - 0s - loss: 1.4038e-04 - 65ms/epoch - 5ms/step
# Epoch 40/50
# 14/14 - 0s - loss: 1.3767e-04 - 65ms/epoch - 5ms/step
# Epoch 41/50
# 14/14 - 0s - loss: 1.3795e-04 - 66ms/epoch - 5ms/step
# Epoch 42/50
# 14/14 - 0s - loss: 1.3538e-04 - 65ms/epoch - 5ms/step
# Epoch 43/50
# 14/14 - 0s - loss: 1.3485e-04 - 68ms/epoch - 5ms/step
# Epoch 44/50
# 14/14 - 0s - loss: 1.3391e-04 - 67ms/epoch - 5ms/step
# Epoch 45/50
# 14/14 - 0s - loss: 1.3310e-04 - 66ms/epoch - 5ms/step
# Epoch 46/50
# 14/14 - 0s - loss: 1.3162e-04 - 66ms/epoch - 5ms/step
# Epoch 47/50
# 14/14 - 0s - loss: 1.3089e-04 - 74ms/epoch - 5ms/step
# Epoch 48/50
# 14/14 - 0s - loss: 1.3170e-04 - 70ms/epoch - 5ms/step
# Epoch 49/50
# 14/14 - 0s - loss: 1.3085e-04 - 68ms/epoch - 5ms/step
# Epoch 50/50
# 14/14 - 0s - loss: 1.3163e-04 - 48ms/epoch - 3ms/step
# 1/1 [==============================] - 0s 344ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# XRP-USD prediction completed.
# XRP-USD: Predicted Price: 0.7078, Risk Score: 0.36%
# [*********************100%***********************]  1 of 1 completed
# Epoch 1/50
# 14/14 - 2s - loss: 0.1006 - 2s/epoch - 142ms/step
# Epoch 2/50
# 14/14 - 0s - loss: 0.0527 - 46ms/epoch - 3ms/step
# Epoch 3/50
# 14/14 - 0s - loss: 0.0268 - 47ms/epoch - 3ms/step
# Epoch 4/50
# 14/14 - 0s - loss: 0.0167 - 53ms/epoch - 4ms/step
# Epoch 5/50
# 14/14 - 0s - loss: 0.0106 - 50ms/epoch - 4ms/step
# Epoch 6/50
# 14/14 - 0s - loss: 0.0059 - 48ms/epoch - 3ms/step
# Epoch 7/50
# 14/14 - 0s - loss: 0.0028 - 50ms/epoch - 4ms/step
# Epoch 8/50
# 14/14 - 0s - loss: 0.0012 - 54ms/epoch - 4ms/step
# Epoch 9/50
# 14/14 - 0s - loss: 6.0395e-04 - 57ms/epoch - 4ms/step
# Epoch 10/50
# 14/14 - 0s - loss: 4.1622e-04 - 48ms/epoch - 3ms/step
# Epoch 11/50
# 14/14 - 0s - loss: 3.6878e-04 - 49ms/epoch - 3ms/step
# Epoch 12/50
# 14/14 - 0s - loss: 3.5048e-04 - 49ms/epoch - 3ms/step
# Epoch 13/50
# 14/14 - 0s - loss: 3.3281e-04 - 48ms/epoch - 3ms/step
# Epoch 14/50
# 14/14 - 0s - loss: 3.1688e-04 - 48ms/epoch - 3ms/step
# Epoch 15/50
# 14/14 - 0s - loss: 3.0333e-04 - 47ms/epoch - 3ms/step
# Epoch 16/50
# 14/14 - 0s - loss: 2.9087e-04 - 48ms/epoch - 3ms/step
# Epoch 17/50
# 14/14 - 0s - loss: 2.8174e-04 - 47ms/epoch - 3ms/step
# Epoch 18/50
# 14/14 - 0s - loss: 2.7185e-04 - 47ms/epoch - 3ms/step
# Epoch 19/50
# 14/14 - 0s - loss: 2.6477e-04 - 48ms/epoch - 3ms/step
# Epoch 20/50
# 14/14 - 0s - loss: 2.5741e-04 - 55ms/epoch - 4ms/step
# Epoch 21/50
# 14/14 - 0s - loss: 2.5047e-04 - 49ms/epoch - 3ms/step
# Epoch 22/50
# 14/14 - 0s - loss: 2.4545e-04 - 52ms/epoch - 4ms/step
# Epoch 23/50
# 14/14 - 0s - loss: 2.4097e-04 - 48ms/epoch - 3ms/step
# Epoch 24/50
# 14/14 - 0s - loss: 2.3589e-04 - 47ms/epoch - 3ms/step
# Epoch 25/50
# 14/14 - 0s - loss: 2.3645e-04 - 49ms/epoch - 3ms/step
# Epoch 26/50
# 14/14 - 0s - loss: 2.2993e-04 - 46ms/epoch - 3ms/step
# Epoch 27/50
# 14/14 - 0s - loss: 2.2893e-04 - 46ms/epoch - 3ms/step
# Epoch 28/50
# 14/14 - 0s - loss: 2.2131e-04 - 53ms/epoch - 4ms/step
# Epoch 29/50
# 14/14 - 0s - loss: 2.1987e-04 - 51ms/epoch - 4ms/step
# Epoch 30/50
# 14/14 - 0s - loss: 2.1791e-04 - 53ms/epoch - 4ms/step
# Epoch 31/50
# 14/14 - 0s - loss: 2.1636e-04 - 51ms/epoch - 4ms/step
# Epoch 32/50
# 14/14 - 0s - loss: 2.1026e-04 - 48ms/epoch - 3ms/step
# Epoch 33/50
# 14/14 - 0s - loss: 2.1063e-04 - 51ms/epoch - 4ms/step
# Epoch 34/50
# 14/14 - 0s - loss: 2.0464e-04 - 49ms/epoch - 4ms/step
# Epoch 35/50
# 14/14 - 0s - loss: 2.0212e-04 - 48ms/epoch - 3ms/step
# Epoch 36/50
# 14/14 - 0s - loss: 2.0144e-04 - 47ms/epoch - 3ms/step
# Epoch 37/50
# 14/14 - 0s - loss: 1.9658e-04 - 48ms/epoch - 3ms/step
# Epoch 38/50
# 14/14 - 0s - loss: 1.9634e-04 - 48ms/epoch - 3ms/step
# Epoch 39/50
# 14/14 - 0s - loss: 1.9171e-04 - 46ms/epoch - 3ms/step
# Epoch 40/50
# 14/14 - 0s - loss: 1.8967e-04 - 45ms/epoch - 3ms/step
# Epoch 41/50
# 14/14 - 0s - loss: 1.8773e-04 - 46ms/epoch - 3ms/step
# Epoch 42/50
# 14/14 - 0s - loss: 1.8519e-04 - 56ms/epoch - 4ms/step
# Epoch 43/50
# 14/14 - 0s - loss: 1.8352e-04 - 45ms/epoch - 3ms/step
# Epoch 44/50
# 14/14 - 0s - loss: 1.8946e-04 - 46ms/epoch - 3ms/step
# Epoch 45/50
# 14/14 - 0s - loss: 1.8056e-04 - 47ms/epoch - 3ms/step
# Epoch 46/50
# 14/14 - 0s - loss: 1.7641e-04 - 48ms/epoch - 3ms/step
# Epoch 47/50
# 14/14 - 0s - loss: 1.7495e-04 - 49ms/epoch - 3ms/step
# Epoch 48/50
# 14/14 - 0s - loss: 1.7660e-04 - 59ms/epoch - 4ms/step
# Epoch 49/50
# 14/14 - 0s - loss: 1.7070e-04 - 48ms/epoch - 3ms/step
# Epoch 50/50
# 14/14 - 0s - loss: 1.6902e-04 - 50ms/epoch - 4ms/step
# 1/1 [==============================] - 0s 313ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# ETH-USD prediction completed.
# ETH-USD: Predicted Price: 1781.9805, Risk Score: 0.00%
# [*********************100%***********************]  1 of 1 completed
# Epoch 1/50
# 13/13 - 2s - loss: 0.0476 - 2s/epoch - 152ms/step
# Epoch 2/50
# 13/13 - 0s - loss: 0.0237 - 45ms/epoch - 3ms/step
# Epoch 3/50
# 13/13 - 0s - loss: 0.0140 - 43ms/epoch - 3ms/step
# Epoch 4/50
# 13/13 - 0s - loss: 0.0086 - 46ms/epoch - 4ms/step
# Epoch 5/50
# 13/13 - 0s - loss: 0.0042 - 46ms/epoch - 4ms/step
# Epoch 6/50
# 13/13 - 0s - loss: 0.0016 - 46ms/epoch - 4ms/step
# Epoch 7/50
# 13/13 - 0s - loss: 5.8378e-04 - 50ms/epoch - 4ms/step
# Epoch 8/50
# 13/13 - 0s - loss: 3.4179e-04 - 57ms/epoch - 4ms/step
# Epoch 9/50
# 13/13 - 0s - loss: 3.2100e-04 - 55ms/epoch - 4ms/step
# Epoch 10/50
# 13/13 - 0s - loss: 3.0623e-04 - 49ms/epoch - 4ms/step
# Epoch 11/50
# 13/13 - 0s - loss: 2.8781e-04 - 61ms/epoch - 5ms/step
# Epoch 12/50
# 13/13 - 0s - loss: 2.7493e-04 - 45ms/epoch - 3ms/step
# Epoch 13/50
# 13/13 - 0s - loss: 2.6375e-04 - 44ms/epoch - 3ms/step
# Epoch 14/50
# 13/13 - 0s - loss: 2.5356e-04 - 45ms/epoch - 3ms/step
# Epoch 15/50
# 13/13 - 0s - loss: 2.4595e-04 - 44ms/epoch - 3ms/step
# Epoch 16/50
# 13/13 - 0s - loss: 2.3443e-04 - 60ms/epoch - 5ms/step
# Epoch 17/50
# 13/13 - 0s - loss: 2.2876e-04 - 64ms/epoch - 5ms/step
# Epoch 18/50
# 13/13 - 0s - loss: 2.1923e-04 - 65ms/epoch - 5ms/step
# Epoch 19/50
# 13/13 - 0s - loss: 2.1375e-04 - 63ms/epoch - 5ms/step
# Epoch 20/50
# 13/13 - 0s - loss: 2.0612e-04 - 71ms/epoch - 5ms/step
# Epoch 21/50
# 13/13 - 0s - loss: 1.9963e-04 - 63ms/epoch - 5ms/step
# Epoch 22/50
# 13/13 - 0s - loss: 1.9805e-04 - 61ms/epoch - 5ms/step
# Epoch 23/50
# 13/13 - 0s - loss: 1.9134e-04 - 61ms/epoch - 5ms/step
# Epoch 24/50
# 13/13 - 0s - loss: 1.8615e-04 - 61ms/epoch - 5ms/step
# Epoch 25/50
# 13/13 - 0s - loss: 1.8274e-04 - 66ms/epoch - 5ms/step
# Epoch 26/50
# 13/13 - 0s - loss: 1.8078e-04 - 61ms/epoch - 5ms/step
# Epoch 27/50
# 13/13 - 0s - loss: 1.7577e-04 - 68ms/epoch - 5ms/step
# Epoch 28/50
# 13/13 - 0s - loss: 1.7500e-04 - 62ms/epoch - 5ms/step
# Epoch 29/50
# 13/13 - 0s - loss: 1.7127e-04 - 66ms/epoch - 5ms/step
# Epoch 30/50
# 13/13 - 0s - loss: 1.6952e-04 - 64ms/epoch - 5ms/step
# Epoch 31/50
# 13/13 - 0s - loss: 1.6714e-04 - 61ms/epoch - 5ms/step
# Epoch 32/50
# 13/13 - 0s - loss: 1.6714e-04 - 62ms/epoch - 5ms/step
# Epoch 33/50
# 13/13 - 0s - loss: 1.6362e-04 - 63ms/epoch - 5ms/step
# Epoch 34/50
# 13/13 - 0s - loss: 1.6234e-04 - 63ms/epoch - 5ms/step
# Epoch 35/50
# 13/13 - 0s - loss: 1.6034e-04 - 64ms/epoch - 5ms/step
# Epoch 36/50
# 13/13 - 0s - loss: 1.5941e-04 - 62ms/epoch - 5ms/step
# Epoch 37/50
# 13/13 - 0s - loss: 1.5852e-04 - 62ms/epoch - 5ms/step
# Epoch 38/50
# 13/13 - 0s - loss: 1.5957e-04 - 62ms/epoch - 5ms/step
# Epoch 39/50
# 13/13 - 0s - loss: 1.5748e-04 - 62ms/epoch - 5ms/step
# Epoch 40/50
# 13/13 - 0s - loss: 1.5507e-04 - 63ms/epoch - 5ms/step
# Epoch 41/50
# 13/13 - 0s - loss: 1.5227e-04 - 65ms/epoch - 5ms/step
# Epoch 42/50
# 13/13 - 0s - loss: 1.5231e-04 - 66ms/epoch - 5ms/step
# Epoch 43/50
# 13/13 - 0s - loss: 1.5030e-04 - 70ms/epoch - 5ms/step
# Epoch 44/50
# 13/13 - 0s - loss: 1.4910e-04 - 65ms/epoch - 5ms/step
# Epoch 45/50
# 13/13 - 0s - loss: 1.5029e-04 - 65ms/epoch - 5ms/step
# Epoch 46/50
# 13/13 - 0s - loss: 1.4756e-04 - 61ms/epoch - 5ms/step
# Epoch 47/50
# 13/13 - 0s - loss: 1.4709e-04 - 66ms/epoch - 5ms/step
# Epoch 48/50
# 13/13 - 0s - loss: 1.4557e-04 - 65ms/epoch - 5ms/step
# Epoch 49/50
# 13/13 - 0s - loss: 1.4430e-04 - 68ms/epoch - 5ms/step
# Epoch 50/50
# 13/13 - 0s - loss: 1.4393e-04 - 56ms/epoch - 4ms/step
# 1/1 [==============================] - 0s 347ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# XDC-USD prediction completed.
# XDC-USD: Predicted Price: 0.0584, Risk Score: 0.00%
# [*********************100%***********************]  1 of 1 completed
# Epoch 1/50
# 9/9 - 2s - loss: 0.0566 - 2s/epoch - 218ms/step
# Epoch 2/50
# 9/9 - 0s - loss: 0.0353 - 33ms/epoch - 4ms/step
# Epoch 3/50
# 9/9 - 0s - loss: 0.0210 - 33ms/epoch - 4ms/step
# Epoch 4/50
# 9/9 - 0s - loss: 0.0134 - 34ms/epoch - 4ms/step
# Epoch 5/50
# 9/9 - 0s - loss: 0.0109 - 32ms/epoch - 4ms/step
# Epoch 6/50
# 9/9 - 0s - loss: 0.0102 - 35ms/epoch - 4ms/step
# Epoch 7/50
# 9/9 - 0s - loss: 0.0093 - 33ms/epoch - 4ms/step
# Epoch 8/50
# 9/9 - 0s - loss: 0.0083 - 32ms/epoch - 4ms/step
# Epoch 9/50
# 9/9 - 0s - loss: 0.0074 - 32ms/epoch - 4ms/step
# Epoch 10/50
# 9/9 - 0s - loss: 0.0066 - 32ms/epoch - 4ms/step
# Epoch 11/50
# 9/9 - 0s - loss: 0.0058 - 31ms/epoch - 3ms/step
# Epoch 12/50
# 9/9 - 0s - loss: 0.0051 - 30ms/epoch - 3ms/step
# Epoch 13/50
# 9/9 - 0s - loss: 0.0044 - 40ms/epoch - 4ms/step
# Epoch 14/50
# 9/9 - 0s - loss: 0.0038 - 32ms/epoch - 4ms/step
# Epoch 15/50
# 9/9 - 0s - loss: 0.0033 - 32ms/epoch - 4ms/step
# Epoch 16/50
# 9/9 - 0s - loss: 0.0029 - 33ms/epoch - 4ms/step
# Epoch 17/50
# 9/9 - 0s - loss: 0.0025 - 34ms/epoch - 4ms/step
# Epoch 18/50
# 9/9 - 0s - loss: 0.0023 - 34ms/epoch - 4ms/step
# Epoch 19/50
# 9/9 - 0s - loss: 0.0021 - 32ms/epoch - 4ms/step
# Epoch 20/50
# 9/9 - 0s - loss: 0.0019 - 33ms/epoch - 4ms/step
# Epoch 21/50
# 9/9 - 0s - loss: 0.0018 - 33ms/epoch - 4ms/step
# Epoch 22/50
# 9/9 - 0s - loss: 0.0018 - 34ms/epoch - 4ms/step
# Epoch 23/50
# 9/9 - 0s - loss: 0.0017 - 33ms/epoch - 4ms/step
# Epoch 24/50
# 9/9 - 0s - loss: 0.0017 - 34ms/epoch - 4ms/step
# Epoch 25/50
# 9/9 - 0s - loss: 0.0017 - 34ms/epoch - 4ms/step
# Epoch 26/50
# 9/9 - 0s - loss: 0.0016 - 34ms/epoch - 4ms/step
# Epoch 27/50
# 9/9 - 0s - loss: 0.0016 - 35ms/epoch - 4ms/step
# Epoch 28/50
# 9/9 - 0s - loss: 0.0016 - 33ms/epoch - 4ms/step
# Epoch 29/50
# 9/9 - 0s - loss: 0.0016 - 34ms/epoch - 4ms/step
# Epoch 30/50
# 9/9 - 0s - loss: 0.0016 - 35ms/epoch - 4ms/step
# Epoch 31/50
# 9/9 - 0s - loss: 0.0016 - 44ms/epoch - 5ms/step
# Epoch 32/50
# 9/9 - 0s - loss: 0.0016 - 33ms/epoch - 4ms/step
# Epoch 33/50
# 9/9 - 0s - loss: 0.0016 - 32ms/epoch - 4ms/step
# Epoch 34/50
# 9/9 - 0s - loss: 0.0016 - 34ms/epoch - 4ms/step
# Epoch 35/50
# 9/9 - 0s - loss: 0.0016 - 35ms/epoch - 4ms/step
# Epoch 36/50
# 9/9 - 0s - loss: 0.0015 - 34ms/epoch - 4ms/step
# Epoch 37/50
# 9/9 - 0s - loss: 0.0015 - 35ms/epoch - 4ms/step
# Epoch 38/50
# 9/9 - 0s - loss: 0.0015 - 35ms/epoch - 4ms/step
# Epoch 39/50
# 9/9 - 0s - loss: 0.0015 - 34ms/epoch - 4ms/step
# Epoch 40/50
# 9/9 - 0s - loss: 0.0015 - 41ms/epoch - 5ms/step
# Epoch 41/50
# 9/9 - 0s - loss: 0.0015 - 32ms/epoch - 4ms/step
# Epoch 42/50
# 9/9 - 0s - loss: 0.0015 - 33ms/epoch - 4ms/step
# Epoch 43/50
# 9/9 - 0s - loss: 0.0015 - 42ms/epoch - 5ms/step
# Epoch 44/50
# 9/9 - 0s - loss: 0.0015 - 33ms/epoch - 4ms/step
# Epoch 45/50
# 9/9 - 0s - loss: 0.0015 - 33ms/epoch - 4ms/step
# Epoch 46/50
# 9/9 - 0s - loss: 0.0015 - 38ms/epoch - 4ms/step
# Epoch 47/50
# 9/9 - 0s - loss: 0.0015 - 33ms/epoch - 4ms/step
# Epoch 48/50
# 9/9 - 0s - loss: 0.0015 - 33ms/epoch - 4ms/step
# Epoch 49/50
# 9/9 - 0s - loss: 0.0015 - 33ms/epoch - 4ms/step
# Epoch 50/50
# 9/9 - 0s - loss: 0.0015 - 32ms/epoch - 4ms/step
# 1/1 [==============================] - 0s 328ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# MCH-USD prediction completed.
# MCH-USD: Predicted Price: 0.0173, Risk Score: 83.85%
# [*********************100%***********************]  1 of 1 completed
# Epoch 1/50
